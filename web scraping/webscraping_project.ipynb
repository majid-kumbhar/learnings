# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
import numpy as np

# %%
url = 'https://en.wikipedia.org/wiki/List_of_largest_companies_by_revenue'
page = requests.get(url)

# %%
soup = BeautifulSoup(page.text, 'html')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-enabled vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of largest companies by revenue - Wikipedia
#   </title>
#   <script>
# ...

# %%
tab = soup.find('table')

# %%
word_title = tab.find_all('th')[:10]

# %%
world_table_title = [title.text.strip() for title in word_title] 
print(world_table_title)
# Out:
# ['Rank', 'Name', 'Industry', 'Revenue', 'Profit', 'Employees', 'Headquarters[note 1]', 'State-owned', 'Ref.', 'USD millions']

# %%
world_table_title[6]= world_table_title[6].replace('Headquarters[note 1]','Headquarters')

# %%
df1= pd.DataFrame(columns = world_table_title)
df1
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Industry, Revenue, Profit, Employees, Headquarters, State-owned, Ref., USD millions]
# Index: []

# %%
df=df1.drop(columns={"USD millions"})
df
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Industry, Revenue, Profit, Employees, Headquarters, State-owned, Ref.]
# Index: []

# %%
column_data = tab.find_all('tr')

# %%
mydata = []
for row in column_data:
    row_data = row.find_all('td')
    ind_row_data = [data.text.strip() for data in row_data]
    mydata.append(ind_row_data)

del mydata[:2]
for i in range(len(mydata)):
    mydata[i].insert(0,i+1)

mydata
# print(mydata)
for data in mydata:
    print(data)
    # length = len(df)
    # print(length)
    # df.loc[length] = data
    # print(df[0])


del df['State-owned'] 
del df['Ref.']
# Out:
# [1, 'Walmart', 'Retail', '$648,125', '$15,511', '2,100,000', 'United States', '', '[1]']
# [2, 'Amazon', 'Retail', '$574,785', '$30,425', '1,525,000', 'United States', '', '[4]']
# [3, 'State Grid Corporation of China', 'Electricity', '$545,948', '$9,204', '1,361,423', 'China', '', '[5]']
# [4, 'Saudi Aramco', 'Oil and gas', '$494,890', '$129,699', '73,311', 'Saudi Arabia', '', '[6]']
# [5, 'China Petrochemical Corporation', 'Oil and gas', '$429,700', '$9,393', '513,434', 'China', '', '[7]']
# [6, 'China National Petroleum Corporation', 'Oil and gas', '$421,714', '$21,294', '1,026,301', 'China', '', '[8]']
# [7, 'Vitol', 'Commodities', '$400,000', '$13,000', '1,560', 'Switzerland', '', '[9][10]']
# [8, 'Apple', 'Information technology', '$383,482', '$96,995', '161,000', 'United States', '', '[11]']
# [9, 'UnitedHealth Group', 'Healthcare', '$371,622', '$22,381', '440,000', 'United States', '', '[12]']
# ...

# %%
df.to_csv("mydata.csv",index=False)

# %%
table = soup.find_all('table')[1]
table
# Out:
# <table class="wikitable sortable plainrowheaders" style="text-align: center">
# <caption>Breakdown by country
# </caption>
# <tbody><tr>
# <th scope="col">Rank
# </th>
# <th scope="col">Country
# </th>
# <th scope="col">Companies
# </th></tr>
# <tr>
# <th scope="row">1
# </th>
# <td style="text-align: left;"><span class="flagicon"><span class="mw-image-border" typeof="mw:File"><span><img alt="" class="mw-file-element" data-file-height="650" data-file-width="1235" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/23px-Flag_of_the_United_States.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/35px-Flag_of_the_United_States.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/46px-Flag_of_the_United_States.svg.png 2x" width="23"/></span></span> </span><a href="/wiki/United_States" title="United States">United States of America</a></td>
# <td>23
# ...

# %%
second_data = table.find_all('th')[:3]
second_data
# Out:
# [<th scope="col">Rank
#  </th>,
#  <th scope="col">Country
#  </th>,
#  <th scope="col">Companies
#  </th>]

# %%
breakdown_world_titles = [country.text.strip() for country in second_data]
breakdown_world_titles
# Out:
# ['Rank', 'Country', 'Companies']

# %%
df1 = pd.DataFrame(columns=breakdown_world_titles)
df1
# Out:
# Empty DataFrame
# Columns: [Rank, Country, Companies]
# Index: []

# %%
my_data = table.find_all('tr')
my_data
# Out:
# [<tr>
#  <th scope="col">Rank
#  </th>
#  <th scope="col">Country
#  </th>
#  <th scope="col">Companies
#  </th></tr>,
#  <tr>
#  <th scope="row">1
#  </th>
#  <td style="text-align: left;"><span class="flagicon"><span class="mw-image-border" typeof="mw:File"><span><img alt="" class="mw-file-element" data-file-height="650" data-file-width="1235" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/23px-Flag_of_the_United_States.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/35px-Flag_of_the_United_States.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/46px-Flag_of_the_United_States.svg.png 2x" width="23"/></span></span> </span><a href="/wiki/United_States" title="United States">United States of America</a></td>
#  <td>23
#  </td></tr>,
#  <tr>
#  <th scope="row">2
#  </th>
# ...

# %%
mydata2 = []
for row in my_data:
    row_data = row.find_all('td')
    ind_row_data = [data.text.strip() for data in row_data]
    mydata2.append(ind_row_data)
del mydata2[:1]
for i in range(len(mydata2)):
    mydata2[i].insert(0,i+1)

mydata2    
    
for data in mydata2:
    length = len(df1)
    df1.loc[length] = data

# %%
df1.to_csv(r"Breakdown_by_country.csv", index = False)
